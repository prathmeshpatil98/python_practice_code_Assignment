# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x, y)

# %%
data = pd.read_csv("cars93.csv")
data
# Out:
#    Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0         Acura  Integra    Small   15.9        25         Driver only
# 1         Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2          Audi       90  Compact   29.1        20         Driver only
# 3          Audi      100  Midsize   37.7        19  Driver & Passenger
# 4           BMW     535i  Midsize   30.0        22         Driver only
# ..          ...      ...      ...    ...       ...                 ...
# 88   Volkswagen  Eurovan      Van   19.7        17  Driver & Passenger
# 89   Volkswagen   Passat  Compact   20.0        21  Driver & Passenger
# 90   Volkswagen  Corrado   Sporty   23.3        18  Driver & Passenger
# 91        Volvo      240  Compact   22.7        21         Driver only
# 92        Volvo      850  Midsize   26.7        20  Driver & Passenger
#
#     Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0          140           5            26.5          11.0
# ...

# %%
plt.figure(figsize=(8,8))
plt.plot(data['Price'],data['Manufacturer'])
plt.ylabel("Manufacturer")
plt.xlabel("Price")
plt.title("This is the Chart of Manufacturer and Price")
# Out:
# Text(0.5, 1.0, 'This is the Chart of Manufacturer and Price')

# %%
plt.scatter(data['Price'],data['Manufacturer'])
plt.ylabel("Manufacturer")
plt.xlabel("Price")
plt.title("This is the Chart of Manufacturer and Price")
plt.show()

# %%
plt.hist(data['Luggage.room'],bins = 10)
plt.show()

# %%
result = data['AirBags'].value_counts()
x = result.index
y = result.values

plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>

# %%
plt.pie(y , labels=x, autopct='%1.1f%%')
plt.show()

# %%
type_value = data['Type'].value_counts()
type_value
# Out:
# Type
# Midsize    22
# Small      21
# Compact    16
# Sporty     14
# Large      11
# Van         9
# Name: count, dtype: int64

# %%
x = type_value.index
y = type_value.values

# %%
data.isna().sum()
# Out:
# Manufacturer       0
# Model              0
# Type               0
# Price              0
# MPG.city           0
# AirBags           14
# Horsepower         0
# Passengers         0
# Rear.seat.room     2
# Luggage.room      11
# dtype: int64

# %%
plt.bar(data['Type'],height=data['Price'])
plt.xlabel("Type of Vehicle")
plt.ylabel("Price of the Vehicle")
plt.show()

# %%
import seaborn as sns
dataset = pd.read_csv("Iris.csv")

# %%
plt.subplot(2,2,1)
plt.scatter(dataset['Sepal_Length'],dataset['Sepal_Width'])
plt.subplot(2,2,2)
plt.scatter(dataset['Sepal_Length'],dataset['Petal_Width'])
plt.subplot(2,2,3)
plt.bar(dataset['Species'],height=dataset['Petal_Width'])
# Out:
# <BarContainer object of 150 artists>

# %%
sns.scatterplot(dataset,x="Sepal_Length",y= 'Sepal_Width')
# Out:
# <Axes: xlabel='Sepal_Length', ylabel='Sepal_Width'>

# %%
plt.figure(figsize=(10,10))
sns.pairplot(dataset,hue="Species")

# %%
sns.countplot(data, x="AirBags",hue="Type")
# Out:
# <Axes: xlabel='AirBags', ylabel='count'>

# %%
dataset1 = dataset.drop("Species",axis=1)
dataset1.corr()
# Out:
#               Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# Sepal_Length      1.000000    -0.109369      0.871754     0.817954
# Sepal_Width      -0.109369     1.000000     -0.420516    -0.356544
# Petal_Length      0.871754    -0.420516      1.000000     0.962757
# Petal_Width       0.817954    -0.356544      0.962757     1.000000

# %%
sns.heatmap(dataset1.corr(),annot=True)
# Out:
# <Axes: >
